# %% [markdown]
# #Clustering Menggunakan Algoritma K-Medoids (dengan Parameter Manual)
#
# Dataset: https://www.kaggle.com/datasets/ankitverma2010/ecommerce-customer-churn-analysis-and-prediction
#
# Setelah ditentukan fitur-fitur yang akan digunakan sesuai dengan hasil visualisasi di Colab0: https://colab.research.google.com/drive/12xwqqv7F0ZF7hytN2U5kmlGr0_lHeOhG?ouid=106950143032811372632&usp=drive_link
#
# Maka, dibuatlah clustering dengan menggunakan algoritma K-Medoids yang bertujuan untuk memahami karakter customer pada e-commerce XYZ.
#
# Parameter algoritma yang digunakan yaitu parameter manual (berdasarkan rangkuman parameter https://docs.google.com/spreadsheets/d/1SwdHlndnVU8mGfc1X6n9RxK3bcWqKYSO6sVfMsIndkU/edit?usp=sharing ) yaitu Skema 2-9.
#
#
# Fitur yang dipakai adalah 3 fitur yang paling berkolerasi satu sama lain yaitu:
#
# 1. OrderCount
# 2. CouponUsed
# 3. HourSpendOnApp

# %%
# !pip install scikit-learn-extra
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 9.4 MB/s eta 0:00:00
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn_extra.cluster import KMedoids

# %%
#Data Loading

import pandas as pd

url = "https://github.com/ranidsr/projekmsib/raw/main/E%20Commerce%20Dataset.xlsx"
df = pd.read_excel(url, sheet_name='E Comm')
df
# Out:
#       CustomerID  Churn  Tenure PreferredLoginDevice  CityTier  \
# 0          50001      1     4.0         Mobile Phone         3
# 1          50002      1     NaN                Phone         1
# 2          50003      1     NaN                Phone         1
# 3          50004      1     0.0                Phone         3
# 4          50005      1     0.0                Phone         1
# ...          ...    ...     ...                  ...       ...
# 5625       55626      0    10.0             Computer         1
# 5626       55627      0    13.0         Mobile Phone         1
# 5627       55628      0     1.0         Mobile Phone         1
# 5628       55629      0    23.0             Computer         3
# 5629       55630      0     8.0         Mobile Phone         1
#
#       WarehouseToHome PreferredPaymentMode  Gender  HourSpendOnApp  \
# 0                 6.0           Debit Card  Female             3.0
# 1                 8.0                  UPI    Male             3.0
# ...

# %%
#Update Dataframe berdasarkan fitur yang digunakan saja

df=df[['OrderCount', 'CouponUsed', 'HourSpendOnApp']]
df
# Out:
#       OrderCount  CouponUsed  HourSpendOnApp
# 0            1.0         1.0             3.0
# 1            1.0         0.0             3.0
# 2            1.0         0.0             2.0
# 3            1.0         0.0             2.0
# 4            1.0         1.0             NaN
# ...          ...         ...             ...
# 5625         2.0         1.0             3.0
# 5626         2.0         1.0             3.0
# 5627         2.0         1.0             3.0
# 5628         2.0         2.0             4.0
# 5629         2.0         2.0             3.0
#
# [5630 rows x 3 columns]

# %%
#Lihat rangkuman data apakah ada missing values

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5630 entries, 0 to 5629
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   OrderCount      5372 non-null   float64
#  1   CouponUsed      5374 non-null   float64
#  2   HourSpendOnApp  5375 non-null   float64
# dtypes: float64(3)
# memory usage: 132.1 KB

# %%
#Handling Missing Values
import numpy as np

df.dropna(axis=0, how='any', subset=(['OrderCount', 'CouponUsed', 'HourSpendOnApp']), inplace=True)
df.reset_index()
df = pd.concat([df], ignore_index=True)
# Out:
# <ipython-input-6-cef5e865a2ed>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(axis=0, how='any', subset=(['OrderCount', 'CouponUsed', 'HourSpendOnApp']), inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4861 entries, 0 to 4860
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   OrderCount      4861 non-null   float64
#  1   CouponUsed      4861 non-null   float64
#  2   HourSpendOnApp  4861 non-null   float64
# dtypes: float64(3)
# memory usage: 114.1 KB

# %%
import seaborn as sns

plt.figure(figsize = (18,15))
sns.heatmap(df.corr() , annot = True , cmap = 'Blues')
# Out:
# <Axes: >

# %%
from sklearn.datasets import make_blobs
from sklearn.metrics import silhouette_score
from sklearn_extra.cluster import KMedoids
from sklearn.preprocessing import StandardScaler

# %%
X, _ = make_blobs(random_state=42)
X = StandardScaler().fit_transform(X)
X
# Out:
# array([[-1.25730111e+00, -1.52486616e+00],
#        [ 1.49987157e+00, -1.13176845e-01],
#        [-2.64088262e-01,  1.24865264e+00],
#        [ 1.62314632e+00, -1.39593967e-01],
#        [-1.00530686e+00, -1.20418507e+00],
#        [ 1.12246973e+00, -1.05025949e-02],
#        [-9.65766460e-02,  1.31554799e+00],
#        [ 1.28373194e+00,  1.32162508e-01],
#        [ 1.34999484e+00,  2.26643082e-01],
#        [-4.06659748e-01,  1.22287278e+00],
#        [-2.79758830e-01,  1.18196549e+00],
#        [-1.03257092e+00, -1.08887417e+00],
#        [-9.70966366e-01, -1.24494164e+00],
#        [-3.97317321e-01,  9.80016554e-01],
#        [-1.13911386e-02,  1.19130423e+00],
#        [-1.30418181e+00, -1.21628414e+00],
#        [-1.02227199e+00, -1.16302698e+00],
#        [-1.80940096e-01,  1.31987205e+00],
#        [-1.26505471e+00, -1.26707496e+00],
#        [-9.81155064e-01, -1.30207712e+00],
#        [-2.62821222e-01,  1.09287382e+00],
#        [-1.09628417e+00, -1.23811787e+00],
# ...

# %%
#Skema 2
#n_clusters = 5
#method = alternate
#init = random


kmedoids2 = KMedoids(n_clusters=5, method='alternate', init='random')
kmedoids2.fit(X)
# Out:
# KMedoids(init='random', n_clusters=5)

# %%
cluster_labels2 = kmedoids2.labels_

# %%
silhouette_avg2 = silhouette_score(X, cluster_labels2)

# %%
print(f"Silhouette Score di Skema 2: {silhouette_avg2}")
# Out:
# Silhouette Score di Skema 2: 0.5075960322633319

# %%
for i in range(5):
  plt.scatter(X[cluster_labels2 == i, 0], X[cluster_labels2 == i, 1], label=f'Cluster {i+1}')

plt.scatter(kmedoids2.cluster_centers_[:,0], kmedoids2.cluster_centers_[:,1], s=200, c='red', label='Medoids')
plt.legend()
plt.title("K-Medoids Clustering")
plt.xlabel("HourSpendOnApp")
plt.ylabel("CouponUsed")
plt.show()

# %%
#Skema 3
#n_clusters = 5
#method = pam
#init = random


kmedoids3 = KMedoids(n_clusters=5, method='pam', init='random')
kmedoids3.fit(X)
# Out:
# KMedoids(init='random', method='pam', n_clusters=5)

# %%
cluster_labels3 = kmedoids3.labels_

# %%
silhouette_avg3 = silhouette_score(X, cluster_labels3)

# %%
print(f"Silhouette Score di Skema 3: {silhouette_avg3}")
# Out:
# Silhouette Score di Skema 3: 0.5205040026975043

# %%
for i in range(5):
  plt.scatter(X[cluster_labels3 == i, 0], X[cluster_labels3 == i, 1], label=f'Cluster {i+1}')

plt.scatter(kmedoids3.cluster_centers_[:,0], kmedoids3.cluster_centers_[:,1], s=200, c='red', label='Medoids')
plt.legend()
plt.title("K-Medoids Clustering")
plt.xlabel("HourSpendOnApp")
plt.ylabel("CouponUsed")
plt.show()

# %%
#Skema 4
#n_clusters = 5
#method = alternate
#init = k-medoids++


kmedoids4 = KMedoids(n_clusters=5, method='alternate', init='k-medoids++')
kmedoids4.fit(X)
# Out:
# KMedoids(init='k-medoids++', n_clusters=5)

# %%
cluster_labels4 = kmedoids4.labels_

# %%
silhouette_avg4 = silhouette_score(X, cluster_labels4)

# %%
print(f"Silhouette Score di Skema 4: {silhouette_avg4}")
# Out:
# Silhouette Score di Skema 4: 0.5075960322633319

# %%
for i in range(5):
  plt.scatter(X[cluster_labels4 == i, 0], X[cluster_labels4 == i, 1], label=f'Cluster {i+1}')

plt.scatter(kmedoids4.cluster_centers_[:,0], kmedoids4.cluster_centers_[:,1], s=200, c='red', label='Medoids')
plt.legend()
plt.title("K-Medoids Clustering")
plt.xlabel("HourSpendOnApp")
plt.ylabel("CouponUsed")
plt.show()

# %%
#Skema 5
#n_clusters = 5
#method = pam
#init = k-medoids++


kmedoids5 = KMedoids(n_clusters=5, method='pam', init='k-medoids++')
kmedoids5.fit(X)
# Out:
# KMedoids(init='k-medoids++', method='pam', n_clusters=5)

# %%
cluster_labels5 = kmedoids5.labels_

# %%
silhouette_avg5 = silhouette_score(X, cluster_labels5)

# %%
print(f"Silhouette Score di Skema 5: {silhouette_avg5}")
# Out:
# Silhouette Score di Skema 5: 0.5205040026975043

# %%
for i in range(5):
  plt.scatter(X[cluster_labels5 == i, 0], X[cluster_labels5 == i, 1], label=f'Cluster {i+1}')

plt.scatter(kmedoids5.cluster_centers_[:,0], kmedoids5.cluster_centers_[:,1], s=200, c='red', label='Medoids')
plt.legend()
plt.title("K-Medoids Clustering")
plt.xlabel("HourSpendOnApp")
plt.ylabel("CouponUsed")
plt.show()

# %%
#Skema 6
#n_clusters = 10
#method = alternate
#init = random


kmedoids6 = KMedoids(n_clusters=10, method='alternate', init='random')
kmedoids6.fit(X)
# Out:
# KMedoids(init='random', n_clusters=10)

# %%
cluster_labels6 = kmedoids6.labels_

# %%
silhouette_avg6 = silhouette_score(X, cluster_labels6)

# %%
print(f"Silhouette Score di Skema 6: {silhouette_avg6}")
# Out:
# Silhouette Score di Skema 6: 0.4784545672477713

# %%
for i in range(10):
  plt.scatter(X[cluster_labels6 == i, 0], X[cluster_labels6 == i, 1], label=f'Cluster {i+1}')

plt.scatter(kmedoids6.cluster_centers_[:,0], kmedoids6.cluster_centers_[:,1], s=200, c='red', label='Medoids')
plt.legend()
plt.title("K-Medoids Clustering")
plt.xlabel("HourSpendOnApp")
plt.ylabel("CouponUsed")
plt.show()

# %%
#Skema 7
#n_clusters = 10
#method = pam
#init = random


kmedoids7 = KMedoids(n_clusters=10, method='pam', init='random')
kmedoids7.fit(X)
# Out:
# KMedoids(init='random', method='pam', n_clusters=10)

# %%
cluster_labels7 = kmedoids7.labels_

# %%
silhouette_avg7 = silhouette_score(X, cluster_labels7)

# %%
print(f"Silhouette Score di Skema 7: {silhouette_avg7}")
# Out:
# Silhouette Score di Skema 7: 0.3413675184817496

# %%
for i in range(10):
  plt.scatter(X[cluster_labels7 == i, 0], X[cluster_labels7 == i, 1], label=f'Cluster {i+1}')

plt.scatter(kmedoids7.cluster_centers_[:,0], kmedoids7.cluster_centers_[:,1], s=200, c='red', label='Medoids')
plt.legend()
plt.title("K-Medoids Clustering")
plt.xlabel("HourSpendOnApp")
plt.ylabel("CouponUsed")
plt.show()

# %%
#Skema 8
#n_clusters = 10
#method = alternate
#init = k-medoids++


kmedoids8 = KMedoids(n_clusters=10, method='alternate', init='k-medoids++')
kmedoids8.fit(X)
# Out:
# KMedoids(init='k-medoids++', n_clusters=10)

# %%
cluster_labels8 = kmedoids8.labels_

# %%
silhouette_avg8 = silhouette_score(X, cluster_labels8)

# %%
print(f"Silhouette Score di Skema 8: {silhouette_avg8}")
# Out:
# Silhouette Score di Skema 8: 0.34800036648673194

# %%
for i in range(10):
  plt.scatter(X[cluster_labels8 == i, 0], X[cluster_labels8 == i, 1], label=f'Cluster {i+1}')

plt.scatter(kmedoids8.cluster_centers_[:,0], kmedoids8.cluster_centers_[:,1], s=200, c='red', label='Medoids')
plt.legend()
plt.title("K-Medoids Clustering")
plt.xlabel("HourSpendOnApp")
plt.ylabel("CouponUsed")
plt.show()

# %%
#Skema 9
#n_clusters = 10
#method = pam
#init = k-medoids++


kmedoids9 = KMedoids(n_clusters=10, method='pam', init='k-medoids++')
kmedoids9.fit(X)
# Out:
# KMedoids(init='k-medoids++', method='pam', n_clusters=10)

# %%
cluster_labels9 = kmedoids9.labels_

# %%
silhouette_avg9 = silhouette_score(X, cluster_labels9)

# %%
print(f"Silhouette Score di Skema 9: {silhouette_avg9}")
# Out:
# Silhouette Score di Skema 9: 0.3664670615726066

# %%
for i in range(10):
  plt.scatter(X[cluster_labels9 == i, 0], X[cluster_labels9 == i, 1], label=f'Cluster {i+1}')

plt.scatter(kmedoids9.cluster_centers_[:,0], kmedoids9.cluster_centers_[:,1], s=200, c='red', label='Medoids')
plt.legend()
plt.title("K-Medoids Clustering")
plt.xlabel("HourSpendOnApp")
plt.ylabel("CouponUsed")
plt.show()
